# %% [markdown]
# <a href="https://colab.research.google.com/github/HiagoCMWesz/programacao_python/blob/main/brasileirao_estados_soneca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite seu nome: ")
idade = float(input ("Digite sua idade: "))
anos_dormidos = idade/3
print(f"Seu nome é: {nome} e você dormiu {anos_dormidos:.2f} anos")
# Out:
# Digite seu nome: Rafifis
# Digite sua idade: 16
# Seu nome é: Rafifis e você dormiu 5.33 anos

# %%
print("Bem vindo à calculadora do brasileirão\n")
vitorias = int(input("Digite as vitórias do seu time:"))

empates = int(input("Digite os empates do seu time:"))

derrotas = int(input("Digite as derrotas do seu time:"))

pontos = (vitorias*3) + (empates*1) + (derrotas*0)

jogos = (vitorias + empates + derrotas)
print(f"\nSeu time jogou um total de: {jogos} rodadas")
print(f"Seu time fez um total de: {pontos} pontos ")

vitorias_porcentagem = (vitorias/jogos)*100
print(f"Seu time teve uma porcentagem de vitorias igual a: {vitorias_porcentagem}\n")

if (vitorias_porcentagem) <= 35:
  print("ih rapaz, ta dando tudo errado, troca essas ideias ai em")

elif (vitorias_porcentagem) > 35 and vitorias_porcentagem <= 50:
  print("talvez considere trocar as táticas do seu time")

elif (vitorias_porcentagem) > 50 and vitorias_porcentagem <= 70:
  print("parabéns, seu time está bem no campeonato")

else:
  print("só pode ser o flamengo")
# Out:
# Bem vindo à calculadora do brasileirão
#
# Digite as vitórias do seu time:10
# Digite os empates do seu time:10
# Digite as derrotas do seu time:10
#
# Seu time jogou um total de: 30 rodadas
# Seu time fez um total de: 40 pontos
# Seu time teve uma porcentagem de vitorias igual a: 33.33333333333333
#
# ih rapaz, ta dando tudo errado, troca essas ideias ai em

# %%
estados = [
    "AC", "AL", "AP", "AM", "BA", "CE", "DF", "ES", "GO",
    "MA", "MT", "MS", "MG", "PA", "PB", "PR", "PE", "PI",
    "RJ", "RN", "RS", "RO", "RR", "SC", "SP", "SE", "TO"
]

while True:
  estado_digitado = input("Digite seu estado ").upper()

  if estado_digitado in estados:
    print(f"O estado '{estado_digitado}' é válido.")
    break
  else:
    print(f"O estado '{estado_digitado}' não é válido.")
# Out:
# Digite seu estado po
# O estado 'PO' não é válido.
# Digite seu estado rs
# O estado 'RS' é válido.
